# %%
import pandas as pd
# Note values in chart are rounded.
# Note that only a limited number of crash victims in NWT and YK were tested for alcohol and/or drugs, therefore their presence has been assumed to be the same as those among drivers of highway vehicles in the rest of Canada dying within 30 days of the crash

# %%
raw_data = {'Location': ['CAN', 'AB', 'BC', 'MB', 'NB', 'NL', 'NS', 'ON', 'PE', 'QC', 'SK', 'NT', 'NU', 'YK'], 
        'Total # of Crash Deaths': [2297, 414, 427, 79, 61, 40, 62, 678, 6, 381, 139, 5, 0, 5], 
        '# of Fatalities Involving Drugs Alone or Drugs and Alcohol': [974, 182, 181, 40, 41, 17, 23, 296, 2, 133, 51, 2, 0, 2], 
        '% of Fatalities Involving Drugs Alone or Drugs and Alcohol': [42.4, 44.0, 42.4, 50.0, 68.0, 42.9, 36.7, 43.6, 33.3, 34.9, 36.8, 42.4, 0.0, 42.4]}
df = pd.DataFrame(raw_data, columns = ['Location', 'Total # of Crash Deaths', '# of Fatalities Involving Drugs Alone or Drugs and Alcohol', '% of Fatalities Involving Drugs Alone or Drugs and Alcohol'])
df
# Out:
#    Location  Total # of Crash Deaths  \
# 0       CAN                     2297
# 1        AB                      414
# 2        BC                      427
# 3        MB                       79
# 4        NB                       61
# 5        NL                       40
# 6        NS                       62
# 7        ON                      678
# 8        PE                        6
# 9        QC                      381
# 10       SK                      139
# 11       NT                        5
# 12       NU                        0
# 13       YK                        5
#
#     # of Fatalities Involving Drugs Alone or Drugs and Alcohol  \
# 0                                                 974
# 1                                                 182
# 2                                                 181
# 3                                                  40
# 4                                                  41
# 5                                                  17
# 6                                                  23
# 7                                                 296
# 8                                                   2
# 9                                                 133
# 10                                                 51
# 11                                                  2
# 12                                                  0
# 13                                                  2
#
#     % of Fatalities Involving Drugs Alone or Drugs and Alcohol
# 0                                                42.4
# 1                                                44.0
# 2                                                42.4
# 3                                                50.0
# 4                                                68.0
# 5                                                42.9
# 6                                                36.7
# 7                                                43.6
# 8                                                33.3
# 9                                                34.9
# 10                                               36.8
# 11                                               42.4
# 12                                                0.0
# 13                                               42.4

# %%
df.to_csv('affectsofsubabuse.csv')
