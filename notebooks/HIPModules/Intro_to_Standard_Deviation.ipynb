# %% [markdown]
# # Background / Pre-requisites
# Assumes student understands square roots and mean calculation.

# %% [markdown]
# # Introduction
# The standard deviation of a graphed relationship is key to understanding the significance of the relationship and to determine the strength of the relationship.

# %% [markdown]
# # Standard Deviation Overview

# %%
#change the variables in this cell to create your own experiment!

#max height in cm.
height = 175.5

# Number of trials.
N = 100

# %%
# Imports.
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import numpy as np

import math

# Initialize plotly for Jupyter notebooks.
init_notebook_mode(connected=True)

# Initialize data sets.
gx = []
gy = []

# Constant multiple in Boyle's Law.
k = 1

# Boyle's Law is technically PV = k, where k is constant for that specific system, (It varies between systems.)
# and P1V1 = P2V2 is only a result of this relationship. Students do not learn this however.
# For simplicity k is set to 1.

# Standard deviation.
sd = 0.15

# Randomly generate data based on user defined volume and number of trials.
for i in range(0, N):
    temp = np.random.random_sample() * height
    
    # Prevent large outliers. The limit is arbitrary, it is just so the graph looks nice.
    limit = np.random.random_sample() + 1
    while(k/temp > volume/limit):
        temp = np.random.random_sample() * height
    
    outputx = np.random.uniform(temp-sd, temp+sd)
    outputy = np.random.uniform((temp)*(sd/5), (temp)-(sd*5))
    
    gx.append(outputx)
    gy.append(outputy)

# Create a trace.
trace = go.Scatter(
    x = gx,
    y = gy,
    mode = 'markers'
)

# Plot graph
templayout = go.Layout( title = 'Height vs. Age', xaxis = dict(title='Height'), yaxis = dict(title='Age') )
tempdata = [trace]
fig = go.Figure(data = tempdata, layout = templayout)
py.iplot(fig, filename='basic-scatter')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="16fab387-0724-49e2-990f-e2397fd847d6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '16fab387-0724-49e2-990f-e2397fd847d6',
#             [{"mode": "markers", "x": [118.88606566333938, 95.74314492872224, 111.88677761824798, 51.98364920785718, 141.5941151731429, 69.96165979427664, 59.684107911848685, 105.38837300164111, 75.8709891379247, 163.0639100639027, 134.54325396344672, 27.609569711776146, 110.63894212741747, 40.17165186460216, 63.7887819744449, 151.5699770033695, 19.475448031113416, 86.21095603718922, 131.29267561946253, 38.37852284007672, 87.7586443541975, 161.70832993542788, 17.067080597849802, 165.59438925175613, 22.367759737380215, 20.902779684823262, 88.19857417789792, 153.86291326939664, 143.16119134914445, 118.65794953904542, 156.46102625286883, 99.93892120358343, 162.37350936323858, 164.5322694545616, 77.34598935434005, 154.19518938252614, 117.47194905983923, 0.9050239589539348, 59.244532425802475, 91.12198691600182, 99.03054309130562, 40.973360855125236, 39.977091368692555, 65.3136889840234, 72.41139116089225, 158.31860119412448, 106.57423010227438, 14.755263497800291, 171.20052713438153, 92.95701330173058, 151.5656513667596, 92.06174589160372, 93.12445710907173, 62.639768377623845, 23.925293317908967, 86.33365490633702, 153.8421714594857, 166.79453669936154, 40.97312906825438, 60.62131092667563, 67.41882102397732, 137.23013954916067, 1.5338091046467088, 127.66970464104779, 62.083393359327644, 74.99435161299203, 138.0248656800768, 157.8254511557304, 73.39047625197976, 26.71088366196122, 37.340379468752595, 105.48938416182516, 76.70503426394995, 17.779382628707772, 26.392937692149992, 136.42290342925023, 33.09123399498738, 104.31010934491229, 22.02992013302503, 56.33543131277164, 109.00677423181895, 122.52284150671993, 18.20724816545137, 172.8774909031991, 52.24207182419413, 19.8435367396255, 164.79431342338913, 130.01316856758177, 22.64629652436262, 121.69085348004658, 131.40072410683842, 7.393783347721864, 51.84225961140634, 16.09581900106143, 78.86170879451336, 66.02955711023996, 31.35973023358194, 119.61253659068366, 172.62410330375758, 33.4148472654766], "y": [81.14565903085531, 21.324546276551864, 40.12587865462983, 50.291517980789166, 41.54561732758758, 18.94664169989277, 49.74093926949684, 87.74081421368254, 2.4209389998274413, 34.15921797804204, 89.62574689409264, 10.02290683558679, 76.48972123528297, 38.16820216586423, 32.76178577419967, 82.34987909945696, 10.536710136142133, 29.351445972107378, 39.99036219237085, 30.939851150787995, 35.50094110433335, 147.3633306980154, 10.643604036329984, 10.239244713628066, 19.75058603371191, 13.506552697376016, 75.86258952229085, 127.1988075655033, 8.510620476587313, 88.80576623240034, 73.66032543498119, 42.9725381900109, 83.39155949071719, 28.635686824990028, 75.06467683489932, 71.74006467998633, 68.7004258021081, 0.04302278190767432, 39.966410893087016, 28.785431145222763, 80.457802502463, 10.727221258663285, 16.656664055979103, 47.28216011751855, 9.447793138954138, 44.404846102763294, 48.070246114534555, 2.5857786004552574, 43.970747140611884, 4.813231011700234, 74.42685993815951, 48.71718157565905, 86.88643279472865, 60.50027182165023, 17.299498537933346, 32.72476043035833, 5.319906008058497, 54.22628183237122, 20.493456569446746, 14.694295789590228, 17.962800819125142, 108.08081060066245, 0.06522461586938108, 90.76104862592882, 33.570950838145194, 22.106452421457483, 82.5663974911586, 49.95581962138485, 67.7312709275311, 17.62814872387149, 1.3909044600272968, 11.578199837530226, 53.76654681064414, 15.554109304546339, 23.111211679005986, 49.57599316640642, 18.74969659867729, 32.64670183472543, 15.016625736822144, 14.358830011659451, 33.10472681130863, 34.657411566635695, 7.878272393307567, 150.98900658586953, 50.732813487613434, 3.3291682892086856, 41.30812140190204, 91.27750415095181, 4.379087249848127, 60.00249869167942, 88.14251493368197, 4.366421101873272, 21.654241259279793, 2.9431328685764377, 62.3334341779994, 60.65488068950137, 21.490591154012044, 85.46506712577579, 24.177730080046768, 15.330571290710845], "type": "scatter", "uid": "c0a5fb90-85ed-11e8-a525-28cfe9142f7f"}],
#             {"title": "Height vs. Age", "xaxis": {"title": "Height"}, "yaxis": {"title": "Age"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('16fab387-0724-49e2-990f-e2397fd847d6',{});}).then(function(){Plotly.animate('16fab387-0724-49e2-990f-e2397fd847d6');})
#         });</script>

# %% [markdown]
# # Variance
# The formula of standard deviation can be defined as the square root of the variance. The variance can in turn be defined as the average of a set of values’ squared distances from their mean.

# %% [markdown]
# # Exercise
# What is the variance of the data set below? Reorder the code cells using the up and down arrows left of the Run button. If you get the order wrong, you will get an error. Close the notebook and shut it down before trying again.

# %%
#START
values = [1, 2, 3, 4, 5]
print(values)
# Out:
# [1, 2, 3, 4, 5]

# %%
value = sum(values)/len(values) #divide the sum of the list of values by the length of the list
print(value)
# Out:
# 3.0

# %%
for i in range(len(values)): #for every value in the list
  value = i**2 #square the value
  values.append(value) #add it to the list
del values[0:5] #remove the old list values
print(values)
# Out:
# [0, 1, 4, 9, 16]

# %%
value = sum(values)/len(values) #divide the sum of the list of values by the length of the list
print(value)
# Out:
# 6.0

# %%
for i in range(len(values)): #for every value in the list
  value = i - value #subtract the value by the average
  values.append(value) #add it to the list
del values[0:5] #remove the old list values
print(values)
# Out:
# [-6.0, 7.0, -5.0, 8.0, -4.0]

# %%
#END (answer)
print(value)
# Out:
# -4.0

# %%
answer = 6.0

from IPython.display import display 
from ipywidgets import widgets

def f(x):
    temp = -10000
    
    print(text.value)
    try:
        temp = float(text.value)
    except:
        print("Not a num")
    
    if(temp == answer):
        print("Yay!")
    else:
        print("Whoops! Try again!")

text = widgets.Text()
display(text)

text.on_submit(f)
# Out:
# Text(value='')

# %% [markdown]
# You might be wondering why we square. Here’s a simplistic explanation: First, it’s important to understand that a negative standard deviation - distance from the predicted value - does not make sense. Second, in order to relate variance to standard deviation, we need to perform operations that can be undone - when you square a value, you can then square root it. If we took the absolute value, then we couldn’t reverse it in a way that accurately depicts the correlation between data.

# %% [markdown]
# # Standard Deviation of Samples
# We’ve just calculated the standard deviation of a population - a small data set composed of ten values. A sample is only a section of the total population, so if we were to calculate the standard deviation the same way, our values would be skewed. To compensate for this, instead of dividing by the total number of values when calculating the average of the squared differences, we want to divide by the total number of values minus 1.

# %% [markdown]
# # CONCLUSION
# In this section, we introduced standard deviation for populations and samples, and how variance can be used to calculate both.
